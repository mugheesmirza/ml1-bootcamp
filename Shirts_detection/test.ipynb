# %%
# !pip install labelImg

# %%
import os

def rename_images(folder_path):
    # Get a list of all files in the directory
    files = os.listdir(folder_path)
    
    # Filter out image files (you can add more extensions if needed)
    image_extensions = ('.jpg', '.jpeg', '.png', '.gif', '.bmp','.txt')
    image_files = [f for f in files if f.lower().endswith(image_extensions)]
    
    # Sort the image files (optional)
    image_files.sort()

    # Rename the image files
    for index, filename in enumerate(image_files, start=1):
        # Construct the new file name
        new_name = f'gray_{index}{os.path.splitext(filename)[1]}'
        # Create full paths
        old_file = os.path.join(folder_path, filename)
        new_file = os.path.join(folder_path, new_name)
        
        # Rename the file
        os.rename(old_file, new_file)
        print(f'Renamed: {old_file} to {new_file}')

# Specify the folder path here
folder_path = "gray_annotation\gray_shirt"  # Change this to your folder path
rename_images(folder_path)
# Out:
# Renamed: gray_annotation\obj_train_data\gray1.txt to gray_annotation\obj_train_data\gray_1.txt
# Renamed: gray_annotation\obj_train_data\gray10.txt to gray_annotation\obj_train_data\gray_2.txt
# Renamed: gray_annotation\obj_train_data\gray11.txt to gray_annotation\obj_train_data\gray_3.txt
# Renamed: gray_annotation\obj_train_data\gray12.txt to gray_annotation\obj_train_data\gray_4.txt
# Renamed: gray_annotation\obj_train_data\gray13.txt to gray_annotation\obj_train_data\gray_5.txt
# Renamed: gray_annotation\obj_train_data\gray14.txt to gray_annotation\obj_train_data\gray_6.txt
# Renamed: gray_annotation\obj_train_data\gray15.txt to gray_annotation\obj_train_data\gray_7.txt
# Renamed: gray_annotation\obj_train_data\gray16.txt to gray_annotation\obj_train_data\gray_8.txt
# Renamed: gray_annotation\obj_train_data\gray17.txt to gray_annotation\obj_train_data\gray_9.txt
# Renamed: gray_annotation\obj_train_data\gray18.txt to gray_annotation\obj_train_data\gray_10.txt
# ...

# %%
import os

def update_class_in_files(folder_path):
    for filename in os.listdir(folder_path):
        if filename.startswith("white") and filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r') as file:
                lines = file.readlines()

            updated_lines = ['3' + line[1:] for line in lines]

            with open(file_path, 'w') as file:
                file.writelines(updated_lines)

folder_path = r'C:\Users\mughe\ml1\!ML 1 Bootcamp\Shirts_detection\white_annotation\obj_train_data'
update_class_in_files(folder_path)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.yaml")

results = model.train(data="config.yaml", epochs=2)
# Out:
# Ultralytics YOLOv8.2.66  Python-3.9.19 torch-2.4.0+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
import os

from ultralytics import YOLO
import cv2


VIDEOS_DIR = os.path.join('.', 'videos')

video_path = os.path.join(VIDEOS_DIR, 'alpaca1.mp4')
video_path_out = '{}_out.mp4'.format(video_path)

cap = cv2.VideoCapture(0)
ret, frame = cap.read()
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

model_path = os.path.join('.', 'runs', 'detect', 'train', 'weights', 'last.pt')

# Load a model
model = YOLO(model_path)  # load a custom model

threshold = 0.5

while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    # out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 218.9ms
# Speed: 34.4ms preprocess, 218.9ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 97.5ms
# Speed: 0.0ms preprocess, 97.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.1ms
# Speed: 0.0ms preprocess, 89.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.1ms
# Speed: 0.0ms preprocess, 89.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.5ms
# Speed: 0.0ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.1ms
# Speed: 0.0ms preprocess, 61.1ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.9ms
# Speed: 0.0ms preprocess, 75.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
cap.release()

# %%
from flask import Flask, request, jsonify
from ultralytics import YOLO
import cv2
import numpy as np
import os

app = Flask(__name__)

# Define model path
model_path = os.path.join('.', 'runs', 'detect', 'train', 'weights', 'last.pt')

# Load a model
model = YOLO(model_path)

threshold = 0.5

@app.route('/predict', methods=['POST'])
def predict():
    if 'image' not in request.files:
        return jsonify({'error': 'No image file in request'}), 400

    file = request.files['image']
    img_bytes = file.read()

    # Convert bytes to numpy array
    nparr = np.frombuffer(img_bytes, np.uint8)
    img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)

    # Perform detection
    results = model(img)[0]
    predictions = []

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            predictions.append({
                'class': results.names[int(class_id)],
                'bounding_box': {
                    'x1': int(x1),
                    'y1': int(y1),
                    'x2': int(x2),
                    'y2': int(y2)
                },
                'score': score
            })

    return jsonify({'predictions': predictions})

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5000)
