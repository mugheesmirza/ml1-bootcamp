# %% [markdown]
# # Reading Images using PIL & CV2

# %% [markdown]
# ### PIL
#
# #### Installation
#
# ```bash
# pip install Pillow
# ```
#
# #### To load an image
#
# ```python
# from PIL import Image
# img = Image.open(im_path)
# print(type(img))
# print(img)
# display(img)
# ```

# %%
from PIL import Image


im_path = "baboon.jpeg"
img = Image.open(im_path)
print(type(img))
print(img)
display(img)
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x16992FD50A0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %% [markdown]
# #### Converting PIL image to RGB, Graysclae or black n white
#
# Normaly PIL loads an image in RGB format (RED, GREEN, BLUE) format. it will have 3 channels. But a PNG may have an additional 4th channel too.
#
#
# To load image in grayscale using PIL
#
# ```python
# from PIL import Image
# img = Image.load(im_path)
# img.convert("RGB") # to RGB
# img.convert("L") # to grayscale
# img.convert("1") # to black & white
# ```

# %%
from PIL import Image


im_path = "baboon.jpeg"
img = Image.open(im_path)

rgb_img = img.convert("RGB") # if it is in RGBA, then it will remove
                             # its 4th channel and resulting will be in RGB
                             # if it is in grayscale, it will convert grascale value
                             # to equivalent RGB, which will result same grayscale color
display(rgb_img)

grayscale_img = img.convert("L")
display(grayscale_img)

bw_img = img.convert("1")
display(bw_img)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>
# <PIL.Image.Image image mode=L size=225x225>
# <PIL.Image.Image image mode=1 size=225x225>

# %% [markdown]
# #### Resize PIL Image
#
# Write code to resize PIL image

# %%
resized_img = img.resize((100, 100))
resized_img
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %% [markdown]
# #### Rotate PIL Image
#
# Write code to crop PIL image

# %%
rotated_img = img.rotate(45)
rotated_img
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# #### Crop PIL Image
#
# Write code to crop PIL image

# %%
left = 100
top = 100
right = 400
bottom = 400
cropped_img = img.crop((left, top, right, bottom))
cropped_img
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %% [markdown]
# ### CV2
#
# #### Installation
#
# ```bash
# pip install opencv-python
# ```
#
# #### To load an image
#
# cv2 loads an images as numpy array
#
# ```python
# import cv2
# img = cv2.imread(im_path)
# print(type(img))
# print(img)
# display(img)
# ```

# %%
import cv2

im_path = "baboon.jpeg"
img = cv2.imread(im_path)
print(type(img))

# print(img)
display(img)
# Out:
# <class 'numpy.ndarray'>
# array([[[ 49, 101, 108],
#         [ 37,  89,  96],
#         [ 35,  82,  90],
#         ...,
#         [ 65, 107,  96],
#         [ 85, 125, 114],
#         [118, 155, 145]],
#
#        [[ 55, 107, 114],
#         [ 14,  63,  71],
#         [ 54, 101, 109],
#         ...,
#         [ 73, 116, 105],
#         [ 60, 103,  92],
#         [ 30,  76,  64]],
#
#        [[ 51, 100, 108],
#         [ 61, 110, 118],
#         [  8,  55,  63],
#         ...,
#         [ 77, 123, 111],
#         [ 40,  90,  78],
#         [109, 171, 159]],
#
#        ...,
#
#        [[120, 120,  96],
#         [151, 151, 127],
#         [156, 154, 130],
#         ...,
#         [ 84,  96,  98],
#         [ 87,  99, 101],
#         [ 74,  83,  87]],
#
#        [[141, 140, 119],
#         [150, 149, 128],
#         [142, 139, 118],
#         ...,
#         [ 77,  86,  89],
#         [ 94, 103, 107],
#         [ 85,  91,  98]],
#
#        [[110, 107,  92],
#         [ 85,  82,  67],
#         [ 86,  83,  68],
#         ...,
#         [ 51,  58,  61],
#         [ 50,  54,  59],
#         [ 48,  49,  59]]], dtype=uint8)

# %% [markdown]
# #### Display cv2 image
#
# cv2 loads image as np array. So to display it, we have to convert it into PIL image object or use pyplot.
#
# **Using PIL**
#
# ```python
# from PIL import Image
# converted_pil_img = Image.fromarray(cv2_img)
# display(converted_pil_img)
# ```
# **Using PIL**
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.imshow(img, cmap='gray')
# plt.show()
# ```

# %%
# PIL
import cv2
from PIL import Image

cv2_img = cv2.imread(im_path)
converted_pil_img = Image.fromarray(cv2_img)
display(converted_pil_img)

# PIL
import cv2
import matplotlib.pyplot as plt

cv2_img = cv2.imread(im_path)
plt.imshow(cv2_img, cmap='gray')
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# #### CV2 image channels and conversion
#
# Normaly cv2 loads an image into BGR format, while all other libraries loads image into RGB. In cv2 image Red is replaced with Blue.
#
# ```python
# import cv2
# from PIL import Image
#
# cv2_img = cv2.imread(im_path)
# display(Image.fromarray(cv2_img))
# ```
#
# here channels are switched. We can convert into RGB using following code
#
# ```python
# converted_img = cv2.cvtColor(cv2_img, cv2.COLOR_BGR2RGB)
# display(Image.fromarray(converted_img))
# ```
#
# into GRAY SCALE
#
# ```python
# converted_img = cv2.cvtColor(cv2_img, cv2.COLOR_BGR2GRAY)
# display(Image.fromarray(converted_img))
# ```

# %%
import cv2
from PIL import Image

# im_path = "/Users/waqas_temp/Downloads/test/baboon.png"
cv2_img = cv2.imread(im_path)
display(Image.fromarray(cv2_img))

converted_img = cv2.cvtColor(cv2_img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(converted_img))

# converting it into grayscale
converted_img = cv2.cvtColor(cv2_img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(converted_img))

# loading an image into grayscal mode
cv2_img = cv2.imread(im_path, 0)
display(Image.fromarray(cv2_img))
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>
# <PIL.Image.Image image mode=RGB size=225x225>
# <PIL.Image.Image image mode=L size=225x225>
# <PIL.Image.Image image mode=L size=225x225>

# %% [markdown]
# #### Resize CV2 Image
#
# Write code to resize CV2 image

# %%
width, height = 100, 100  
resized_img = cv2.resize(cv2_img, (width, height))
display(Image.fromarray(resized_img))
# Out:
# <PIL.Image.Image image mode=L size=100x100>

# %% [markdown]
# #### Rotate CV2 Image
#
# Write code to rotate CV2 image

# %%
center = (cv2_img.shape[1] // 2, cv2_img.shape[0] // 2)
angle = 45  
scale = 1.0

rotation_matrix = cv2.getRotationMatrix2D(center, angle, scale)

rotated_img = cv2.warpAffine(cv2_img, rotation_matrix, (cv2_img.shape[1], cv2_img.shape[0]))

display(Image.fromarray(rotated_img))
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %% [markdown]
# #### Crop CV2 Image
#
# Write code to crop CV2 image

# %%
x_start, y_start, x_end, y_end = 50, 50, 250, 250
cropped_img = cv2_img[y_start:y_end, x_start:x_end]
display(Image.fromarray(cropped_img))
# Out:
# <PIL.Image.Image image mode=L size=175x175>
